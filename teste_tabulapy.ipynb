# %% [markdown]
# #  Teste da biblioteca tabula_py
#
# link de ref: https://github.com/chezou/tabula-py

# %%
# !java -version
# Out:
# java version "1.8.0_231"
# Java(TM) SE Runtime Environment (build 1.8.0_231-b11)
# Java HotSpot(TM) Client VM (build 25.231-b11, mixed mode)

# %%
# !pip install tabula-py --user
# Out:
# Requirement already satisfied: tabula-py in c:\users\halissonsg\appdata\roaming\python\python38\site-packages (2.2.0)
# Requirement already satisfied: distro in c:\users\halissonsg\appdata\roaming\python\python38\site-packages (from tabula-py) (1.5.0)
# Requirement already satisfied: numpy in c:\users\halissonsg\anaconda3\lib\site-packages (from tabula-py) (1.18.5)
# Requirement already satisfied: pandas>=0.25.3 in c:\users\halissonsg\appdata\roaming\python\python38\site-packages (from tabula-py) (1.2.2)
# Requirement already satisfied: pytz>=2017.3 in c:\users\halissonsg\anaconda3\lib\site-packages (from pandas>=0.25.3->tabula-py) (2020.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\halissonsg\anaconda3\lib\site-packages (from pandas>=0.25.3->tabula-py) (2.8.1)
# Requirement already satisfied: six>=1.5 in c:\users\halissonsg\anaconda3\lib\site-packages (from python-dateutil>=2.7.3->pandas>=0.25.3->tabula-py) (1.15.0)

# %%
import tabula

tabula.environment_info()
# Out:
# Python version:
#     3.8.3 (default, Jul  2 2020, 17:30:36) [MSC v.1916 64 bit (AMD64)]
# Java version:
#     java version "1.8.0_231"
# Java(TM) SE Runtime Environment (build 1.8.0_231-b11)
# Java HotSpot(TM) Client VM (build 25.231-b11, mixed mode)
# tabula-py version: 2.2.0
# platform: Windows-10-10.0.18362-SP0
# uname:
#     uname_result(system='Windows', node='pr197580', release='10', version='10.0.18362', machine='AMD64', processor='Intel64 Family 6 Model 158 Stepping 9, GenuineIntel')
# linux_distribution: ('', '', '')
# mac_ver: ('', ('', '', ''), '')

# %%
pdf_path = "../dados/originais/solicitacao_escolta_solicitacoes.pdf"

# dfs = tabula.read_pdf(pdf_path, columns=[47, 147, 256, 310, 375, 431, 504], guess=False, pages=1)
dfs = tabula.read_pdf(pdf_path, columns=[300, 500, 600, 700, 800, 900], guess=False, pages='all')

# %%
dfs[1]
# Out:
#                                        Unnamed: 0  \
# 0                                             NaN
# 1                                               D
# 2                                          DCCP -
# 3                                             NaN
# 4                                      AISP OESTE
# 5                              Delegacia : DCA II
# 6                                   Nome do Preso
# 7                             MENOR INFRATOR 3072
# 8                             MENOR INFRATOR 3073
# 9                             MENOR INFRATOR 3074
# 10                            MENOR INFRATOR 3075
# 11  Total de presos para escolta na Delegacia : 4
# 12                             Delegacia : 12a DP
# 13                                  Nome do Preso
# 14      CLEITON SANTIAGO DOS SANTOS (Prt.: 94284)
# 15     TARCÍSIO DE OLIVEIRA SANTOS (Prt.: 115544)
# 16  Total de presos para escolta na Delegacia : 2
# 17                             Delegacia : 15a DP
# 18                                  Nome do Preso
# 19    BRENO RICARDO FERREIRA CUTRIM (Prt.: 89451)
# 20                         BRUNO DOS SANTOS PINTO
# 21            WESLEY MOREIRA COSTA (Prt.: 110900)
# 22  Total de presos para escolta na Delegacia : 3
# 23                             Delegacia : 18a DP
# 24                                  Nome do Preso
# 25          RENATO ARAUJO DE MATOS (Prt.: 153852)
# 26  Total de presos para escolta na Delegacia : 1
# 27                             Delegacia : 26a DP
# 28                                            NaN
# 29                                            NaN
# 30                                            NaN
#
#                       GOVERNO DO DISTRITO FEDE            RAL  \
# 0                POLÍCIA CIVIL DO DISTRITO FED           ERAL
# 1                  EPARTAMENTO DE ATIVIDADES E       SPECIAIS
# 2                  DIVISÃO DE CONTROLE E CUSTÓ  DIA DE PRESOS
# 3                   Relação de presos para esc           olta
# 4                                          NaN            NaN
# 5                                          NaN            NaN
# 6                                  Nome da Mãe      Dt. Nasc.
# 7                                          NaN            NaN
# 8                                          NaN            NaN
# 9                                          NaN            NaN
# 10                                         NaN            NaN
# 11                                         NaN            NaN
# 12                                         NaN            NaN
# 13                                 Nome da Mãe      Dt. Nasc.
# 14        TENISIA CARVALHO SANTIAGO DOS SANTOS     29/03/1994
# 15             MARIA DE FÁTIMA OLIVEIRA SANTOS     23/03/1997
# 16                                         NaN            NaN
# 17                                         NaN            NaN
# 18                                 Nome da Mãe      Dt. Nasc.
# 19                       TATIANA MENDES CUTRIM     19/10/1994
# 20                 MARIA DAS GRAÇAS DOS SANTOS     31/10/1991
# 21                      IVANILZA ALVES MOREIRA     01/05/1997
# 22                                         NaN            NaN
# 23                                         NaN            NaN
# 24                                 Nome da Mãe      Dt. Nasc.
# 25                    NOAIDE ARAUJO DOS SANTOS     08/05/1974
# 26                                         NaN            NaN
# 27                                         NaN            NaN
# 28                                Pagina 2 / 4            NaN
# 29  "Brasília - Patrimônio Cultural da Humanid           ade"
# 30                         01/03/2021 05:58:14            NaN
#
#                     Unnamed: 1        Unnamed: 2
# 0                          NaN               NaN
# 1                          NaN               NaN
# 2                          NaN               NaN
# 3                          NaN               NaN
# 4               Data da Escolt    a : 01/03/2021
# 5                          NaN               NaN
# 6                   Ocorrência  Dt/Hora Cadastro
# 7                          NaN  28/02/2021 20:38
# 8                          NaN  28/02/2021 20:38
# 9                          NaN  01/03/2021 00:02
# 10                         NaN  01/03/2021 05:37
# 11                         NaN               NaN
# 12                         NaN               NaN
# 13                  Ocorrência  Dt/Hora Cadastro
# 14   IP No 249 / 2021 - 17a DP  28/02/2021 19:27
# 15  MP No 510316 / 2021 - DCPI  28/02/2021 19:21
# 16                         NaN               NaN
# 17                         NaN               NaN
# 18                  Ocorrência  Dt/Hora Cadastro
# 19   IP No 166 / 2021 - 15a DP  28/02/2021 19:00
# 20   IP No 125 / 2021 - 19a DP  28/02/2021 17:12
# 21   IP No 166 / 2021 - 15a DP  28/02/2021 18:57
# 22                         NaN               NaN
# 23                         NaN               NaN
# 24                  Ocorrência  Dt/Hora Cadastro
# 25   IP No 156 / 2021 - 18a DP  28/02/2021 17:50
# 26                         NaN               NaN
# 27                         NaN               NaN
# 28                         NaN               NaN
# 29                         NaN               NaN
# 30                         NaN               NaN

# %%
import numpy as np

# %%
dfs[1].columns = ['nome_preso', 'nome_mae', 'dt_nascimento', 'ocorrencia', 'dt_cadastro']

# %%
dfs[1]['delegacia'] = nan

# %%
dfs[1]
# Out:
#                                        nome_preso  \
# 0                                             NaN
# 1                                               D
# 2                                          DCCP -
# 3                                             NaN
# 4                                      AISP OESTE
# 5                              Delegacia : DCA II
# 6                                   Nome do Preso
# 7                             MENOR INFRATOR 3072
# 8                             MENOR INFRATOR 3073
# 9                             MENOR INFRATOR 3074
# 10                            MENOR INFRATOR 3075
# 11  Total de presos para escolta na Delegacia : 4
# 12                             Delegacia : 12a DP
# 13                                  Nome do Preso
# 14      CLEITON SANTIAGO DOS SANTOS (Prt.: 94284)
# 15     TARCÍSIO DE OLIVEIRA SANTOS (Prt.: 115544)
# 16  Total de presos para escolta na Delegacia : 2
# 17                             Delegacia : 15a DP
# 18                                  Nome do Preso
# 19    BRENO RICARDO FERREIRA CUTRIM (Prt.: 89451)
# 20                         BRUNO DOS SANTOS PINTO
# 21            WESLEY MOREIRA COSTA (Prt.: 110900)
# 22  Total de presos para escolta na Delegacia : 3
# 23                             Delegacia : 18a DP
# 24                                  Nome do Preso
# 25          RENATO ARAUJO DE MATOS (Prt.: 153852)
# 26  Total de presos para escolta na Delegacia : 1
# 27                             Delegacia : 26a DP
# 28                                            NaN
# 29                                            NaN
# 30                                            NaN
#
#                                       nome_mae  dt_nascimento  \
# 0                POLÍCIA CIVIL DO DISTRITO FED           ERAL
# 1                  EPARTAMENTO DE ATIVIDADES E       SPECIAIS
# 2                  DIVISÃO DE CONTROLE E CUSTÓ  DIA DE PRESOS
# 3                   Relação de presos para esc           olta
# 4                                          NaN            NaN
# 5                                          NaN            NaN
# 6                                  Nome da Mãe      Dt. Nasc.
# 7                                          NaN            NaN
# 8                                          NaN            NaN
# 9                                          NaN            NaN
# 10                                         NaN            NaN
# 11                                         NaN            NaN
# 12                                         NaN            NaN
# 13                                 Nome da Mãe      Dt. Nasc.
# 14        TENISIA CARVALHO SANTIAGO DOS SANTOS     29/03/1994
# 15             MARIA DE FÁTIMA OLIVEIRA SANTOS     23/03/1997
# 16                                         NaN            NaN
# 17                                         NaN            NaN
# 18                                 Nome da Mãe      Dt. Nasc.
# 19                       TATIANA MENDES CUTRIM     19/10/1994
# 20                 MARIA DAS GRAÇAS DOS SANTOS     31/10/1991
# 21                      IVANILZA ALVES MOREIRA     01/05/1997
# 22                                         NaN            NaN
# 23                                         NaN            NaN
# 24                                 Nome da Mãe      Dt. Nasc.
# 25                    NOAIDE ARAUJO DOS SANTOS     08/05/1974
# 26                                         NaN            NaN
# 27                                         NaN            NaN
# 28                                Pagina 2 / 4            NaN
# 29  "Brasília - Patrimônio Cultural da Humanid           ade"
# 30                         01/03/2021 05:58:14            NaN
#
#                     ocorrencia       dt_cadastro
# 0                          NaN               NaN
# 1                          NaN               NaN
# 2                          NaN               NaN
# 3                          NaN               NaN
# 4               Data da Escolt    a : 01/03/2021
# 5                          NaN               NaN
# 6                   Ocorrência  Dt/Hora Cadastro
# 7                          NaN  28/02/2021 20:38
# 8                          NaN  28/02/2021 20:38
# 9                          NaN  01/03/2021 00:02
# 10                         NaN  01/03/2021 05:37
# 11                         NaN               NaN
# 12                         NaN               NaN
# 13                  Ocorrência  Dt/Hora Cadastro
# 14   IP No 249 / 2021 - 17a DP  28/02/2021 19:27
# 15  MP No 510316 / 2021 - DCPI  28/02/2021 19:21
# 16                         NaN               NaN
# 17                         NaN               NaN
# 18                  Ocorrência  Dt/Hora Cadastro
# 19   IP No 166 / 2021 - 15a DP  28/02/2021 19:00
# 20   IP No 125 / 2021 - 19a DP  28/02/2021 17:12
# 21   IP No 166 / 2021 - 15a DP  28/02/2021 18:57
# 22                         NaN               NaN
# 23                         NaN               NaN
# 24                  Ocorrência  Dt/Hora Cadastro
# 25   IP No 156 / 2021 - 18a DP  28/02/2021 17:50
# 26                         NaN               NaN
# 27                         NaN               NaN
# 28                         NaN               NaN
# 29                         NaN               NaN
# 30                         NaN               NaN

# %%
df_delegacias = dfs[1].iloc[:,0].where(dfs[1].iloc[:, 0].str.contains('^Delegacia', na=False)).dropna()
                
# idx_del = df_delegacias.index.to_list()
# df_delegacias.index.max()
# df_delegacias.iloc[-1].split(' : ')[1]

# s_delegacia = dfs[0].iloc[:,3].where(dfs[0].iloc[:, 3].str.contains(' DP', na=False)).dropna()
# for i,v in s_delegacia.items():
#     s_delegacia[i] = v.split(' - ')[1]
    
# s_delegacia
df_delegacias
# Out:
# 5     Delegacia : DCA II
# 12    Delegacia : 12a DP
# 17    Delegacia : 15a DP
# 23    Delegacia : 18a DP
# 27    Delegacia : 26a DP
# Name: nome_preso, dtype: object

# %%
def verifica_presos_folha_anterior(df_folha_atual, df_delegacias):

    str_total_presos = df_folha_atual.iloc[:,0].where(df_folha_atual.iloc[:, 0].str.contains('^Total de presos para escolta na Delegacia', na=False)).dropna()

    presos_folha_anterior = -1
    for idx_total in str_total_presos.index.tolist():
        if idx_total < df_delegacias.index.min():
            presos_folha_anterior = idx_total

    return presos_folha_anterior

# %%
pfa = verifica_presos_folha_anterior(dfs[3], df_delegacias)
pfa
# dfs[2].iloc[:pfa, 5] = dfs[1].iloc[-1, 5]
# dfs[2]
# Out:
# 8

# %%
lista = iter(idx_del)
primeiro = next(lista, 'fim')
# next_val = next(lista, 'fim')
while True:
    next_val = next(lista, 'fim')
    if next_val == 'fim':
        dfs[2].iloc[primeiro:, 5] = df_delegacias[primeiro].split(' : ')[1]
        break
    else:
        dfs[2].iloc[primeiro:next_val, 5] = df_delegacias[primeiro].split(' : ')[1]
        primeiro = next_val
#         next_val = next(lista, 'fim')

# %%
dfs[2]

# %%
def trata_df_pdf(dfs_list):
    
    dfs = dfs_list
    df_delegacias = []
    
    for i in range(len(dfs)):
        
        dfs[i].columns = ['nome_preso', 'nome_mae', 'dt_nascimento', 'ocorrencia', 'dt_cadastro']
        dfs[i]['delegacia'] = nan
        df_delegacias.append(dfs[i].iloc[:,0].where(dfs[i].iloc[:, 0].str.contains('^Delegacia', na=False)).dropna())
        
        if len(df_delegacias[i]) > 0:
            
            pfa = verifica_presos_folha_anterior(dfs[i], df_delegacias[i]) # presos da folha anterior
            if pfa > -1 :
                dfs[i].iloc[:pfa, 5] = df_delegacias[i-1].iloc[-1].split(' : ')[1].strip()
                
            idx_del = df_delegacias[i].index.to_list()
            lista = iter(idx_del)
            primeiro = next(lista, 'fim')
            
            while True:
                next_val = next(lista, 'fim')
                if next_val == 'fim':
                    dfs[i].iloc[primeiro:, 5] = df_delegacias[i][primeiro].split(' : ')[1].strip()
                    break
                else:
                    dfs[i].iloc[primeiro:next_val, 5] = df_delegacias[i][primeiro].split(' : ')[1].strip()
                    primeiro = next_val
        else:
            dfs[i].iloc[:, 5] = df_delegacias[i-1].iloc[-1].split(' : ')[1].strip()

        dfs[i] = dfs[i].loc[dfs[i]['nome_preso'] != 'Nome do Preso']
        dfs[i].dropna(inplace=True)

        # trantando as colunas
        dfs[i]['nome_preso'] = dfs[i]['nome_preso'].str.strip()
    return dfs

# %%
df_tratados = trata_df_pdf(dfs)
# Out:
# <ipython-input-31-6672e555f708>:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfs[i].dropna(inplace=True)
# <ipython-input-31-6672e555f708>:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfs[i]['nome_preso'] = dfs[i]['nome_preso'].str.strip()

# %%
df_tratados[1]
# Out:
#                                      nome_preso  \
# 14    CLEITON SANTIAGO DOS SANTOS (Prt.: 94284)
# 15   TARCÍSIO DE OLIVEIRA SANTOS (Prt.: 115544)
# 19  BRENO RICARDO FERREIRA CUTRIM (Prt.: 89451)
# 20                       BRUNO DOS SANTOS PINTO
# 21          WESLEY MOREIRA COSTA (Prt.: 110900)
# 25        RENATO ARAUJO DE MATOS (Prt.: 153852)
#
#                                 nome_mae dt_nascimento  \
# 14  TENISIA CARVALHO SANTIAGO DOS SANTOS    29/03/1994
# 15       MARIA DE FÁTIMA OLIVEIRA SANTOS    23/03/1997
# 19                 TATIANA MENDES CUTRIM    19/10/1994
# 20           MARIA DAS GRAÇAS DOS SANTOS    31/10/1991
# 21                IVANILZA ALVES MOREIRA    01/05/1997
# 25              NOAIDE ARAUJO DOS SANTOS    08/05/1974
#
#                     ocorrencia       dt_cadastro delegacia
# 14   IP No 249 / 2021 - 17a DP  28/02/2021 19:27    12a DP
# 15  MP No 510316 / 2021 - DCPI  28/02/2021 19:21    12a DP
# 19   IP No 166 / 2021 - 15a DP  28/02/2021 19:00    15a DP
# 20   IP No 125 / 2021 - 19a DP  28/02/2021 17:12    15a DP
# 21   IP No 166 / 2021 - 15a DP  28/02/2021 18:57    15a DP
# 25   IP No 156 / 2021 - 18a DP  28/02/2021 17:50    18a DP

# %%
import pandas as pd
df_final = pd.concat(df_tratados, ignore_index=True)
# for i in range(1, len(df_tratados)):
#     df_tratados[0].concat(df_tratados[i], ignore_index=True)

# %%
df_final
# Out:
#                                            nome_preso  \
# 0               CICERO NOGUEIRA FEITOSA (Prt.: 75150)
# 1       JOÃO PAULO MESQUITA DE OLIVEIRA (Prt.: 70795)
# 2                                      MATEUS MARQUES
# 3                              MARCOS MENDES DA SILVA
# 4    ALYSSON GUILHERME ALVES DOS SANTOS (Prt.: 116734
# 5                                BRUNO CRUZ DE ARAUJO
# 6                          CARLOS DANIEL SOUSA SANTOS
# 7                           WILLIAN NERES DE OLIVEIRA
# 8           CLEITON SANTIAGO DOS SANTOS (Prt.: 94284)
# 9          TARCÍSIO DE OLIVEIRA SANTOS (Prt.: 115544)
# 10        BRENO RICARDO FERREIRA CUTRIM (Prt.: 89451)
# 11                             BRUNO DOS SANTOS PINTO
# 12                WESLEY MOREIRA COSTA (Prt.: 110900)
# 13              RENATO ARAUJO DE MATOS (Prt.: 153852)
# 14                               ADÃO PEREIRA DA MOTA
# 15                   CLÊMILSON SANTANA (Prt.: 123005)
# 16  EDVAN PEREIRA DE FREITAS NASCIMENTO (Prt.: 78703)
# 17            MICHEL MAX SOUSA DA SILVA (Prt.: 62702)
# 18                             PAULO ALVES PIRES NETO
# 19                             EDSON JUNIO BUENO ROSA
# 20                             MAURO DOURADO OLIVEIRA
#
#                                   nome_mae dt_nascimento  \
# 0                   MARIA NOGUEIRA FEITOSA    01/11/1985
# 1           JOSENEIDE MESQUITA DE OLIVEIRA    30/04/1989
# 2                   MARIA ALMEIDA DA SILVA    23/12/1991
# 3                    DEYSE MENDES DE JESUS    02/01/1998
# 4             ) CLAUDINELIA ALVES DA COSTA    23/10/1996
# 5                ANA CÉLIA CRUZ DOS SANTOS    25/11/1999
# 6   MARIA DA CONCEIÇÃO SILVESTRE DOS SANTO  S 27/02/1999
# 7         JOSÉ FRANCISCO DE OLIVEIRA SOUSA    18/10/1993
# 8     TENISIA CARVALHO SANTIAGO DOS SANTOS    29/03/1994
# 9          MARIA DE FÁTIMA OLIVEIRA SANTOS    23/03/1997
# 10                   TATIANA MENDES CUTRIM    19/10/1994
# 11             MARIA DAS GRAÇAS DOS SANTOS    31/10/1991
# 12                  IVANILZA ALVES MOREIRA    01/05/1997
# 13                NOAIDE ARAUJO DOS SANTOS    08/05/1974
# 14               LIBERTINA CARDOSO DE MELO    15/04/1979
# 15                 MARIA APARECIDA SANTANA    28/10/1981
# 16     MARIA PEREIRA DE FREITAS NASCIMENTO    20/06/1984
# 17                   JANETE SOUSA DA SILVA    21/08/1982
# 18                   MARIA DE FATIMA PIRES    01/04/1973
# 19       MARIA FRANCISCA BUENO DE MESQUITA    21/12/2002
# 20                ANTONIA DOURADO OLIVEIRA    20/12/1988
#
#                      ocorrencia       dt_cadastro delegacia
# 0      IP No 109 / 2021 - 5a DP  01/03/2021 00:00     5a DP
# 1       IP No 93 / 2021 - 2a DP  01/03/2021 01:28     5a DP
# 2   MP No 3614316 / 2020 - DCPI  28/02/2021 23:35     5a DP
# 3      MP No 7316 / 2021 - DCPI  28/02/2021 16:09     6a DP
# 4     IP No 192 / 2021 - 13a DP  28/02/2021 19:51    13a DP
# 5     IP No 142 / 2021 - 35a DP  28/02/2021 19:29    13a DP
# 6     IP No 143 / 2021 - 35a DP  28/02/2021 19:34    13a DP
# 7     IP No 191 / 2021 - 13a DP  28/02/2021 19:24    13a DP
# 8     IP No 249 / 2021 - 17a DP  28/02/2021 19:27    12a DP
# 9    MP No 510316 / 2021 - DCPI  28/02/2021 19:21    12a DP
# 10    IP No 166 / 2021 - 15a DP  28/02/2021 19:00    15a DP
# 11    IP No 125 / 2021 - 19a DP  28/02/2021 17:12    15a DP
# 12    IP No 166 / 2021 - 15a DP  28/02/2021 18:57    15a DP
# 13    IP No 156 / 2021 - 18a DP  28/02/2021 17:50    18a DP
# 14   MP No 4426 / 2021 - 26a DP  28/02/2021 23:36    26a DP
# 15    IP No 208 / 2021 - 26a DP  28/02/2021 19:15    26a DP
# 16     IP No 126 / 2021 - 8a DP  28/02/2021 17:22     1a DP
# 17   MP No 290316 / 2021 - DCPI  28/02/2021 23:58    20a DP
# 18    IP No 148 / 2021 - 20a DP  28/02/2021 18:14    20a DP
# 19    IP No 277 / 2021 - 27a DP  28/02/2021 19:41    27a DP
# 20    IP No 278 / 2021 - 27a DP  28/02/2021 19:55    27a DP

# %%
df_final.query('delegacia == "21a DP"')['nome_preso'].tolist()
# Out:
# ['LIDIA REZENDE DO AMARAL (Prt.: 25253)', 'PEDRO IGOR ALVES BERNARDO']

# %%
search = df_final.query('delegacia == "21a DP"')[['nome_preso', 'nome_mae']].to_dict(orient='records')
search
# Out:
# [{'nome_preso': 'LIDIA REZENDE DO AMARAL (Prt.: 25253)',
#   'nome_mae': 'CILIA DE SOUZA REZENDE'},
#  {'nome_preso': 'PEDRO IGOR ALVES BERNARDO',
#   'nome_mae': 'ELIAMAR ALVES NETO BERNARDO'}]

# %%
for row in search:
    nome = row['nome_preso'].split('(')[0].strip()
    print(nome, end='\n')
# Out:
# LIDIA REZENDE DO AMARAL
# PEDRO IGOR ALVES BERNARDO

# %%
df_final['delegacia'].unique().tolist()
# Out:
# ['5a DP',
#  '6a DP',
#  '13a DP',
#  '12a DP',
#  '15a DP',
#  '18a DP',
#  '26a DP',
#  '1a DP',
#  '20a DP',
#  '27a DP']

# %%
from time import perf_counter

# %%
start_for = perf_counter()

conteudo = {}
for p in range(1,40):
    chave = 'p0'+str(p) if p < 10 else 'p'+str(p)
    conteudo[chave] = []

    
lst_delegacias = df_final['delegacia'].unique().tolist()
for delegacia in lst_delegacias:
    
    if delegacia == '1a DP':
        conteudo['p01'] = conteudo['p01'] + df_final.query('delegacia == "1a DP"')[['nome_preso', 'nome_mae']].to_dict(orient='records')

    elif delegacia == '4a DP':
        conteudo['p01'] = conteudo['p01'] + df_final.query('delegacia == "4a DP"')[['nome_preso', 'nome_mae']].to_dict(orient='records')

    elif delegacia == '5a DP':
        conteudo['p05'] = conteudo['p05'] + df_final.query('delegacia == "5a DP"')[['nome_preso', 'nome_mae']].to_dict(orient='records')

    elif delegacia == '6a DP':
        conteudo['p06'] = conteudo['p06'] + df_final.query('delegacia == "6a DP"')[['nome_preso', 'nome_mae']].to_dict(orient='records')

    elif delegacia == '8a DP':
        conteudo['p01'] = conteudo['p01'] + df_final.query('delegacia == "8a DP"')[['nome_preso', 'nome_mae']].to_dict(orient='records')

    elif delegacia == '10a DP':
        conteudo['p01'] = conteudo['p01'] + df_final.query('delegacia == "10a DP"')[['nome_preso', 'nome_mae']].to_dict(orient='records')

    elif delegacia == '11a DP':
        conteudo['p21'] = conteudo['p21'] + df_final.query('delegacia == "11a DP"')[['nome_preso', 'nome_mae']].to_dict(orient='records')

    elif delegacia == '12a DP':
        conteudo['p12'] = conteudo['p12'] + df_final.query('delegacia == "12a DP"')[['nome_preso', 'nome_mae']].to_dict(orient='records')

    elif delegacia == '13a DP':
        conteudo['p13'] = conteudo['p13'] + df_final.query('delegacia == "13a DP"')[['nome_preso', 'nome_mae']].to_dict(orient='records')

    elif delegacia == '14a DP':
        conteudo['p20'] = conteudo['p20'] + df_final.query('delegacia == "14a DP"')[['nome_preso', 'nome_mae']].to_dict(orient='records')

    elif delegacia == '15a DP':
        conteudo['p15'] = conteudo['p15'] + df_final.query('delegacia == "15a DP"')[['nome_preso', 'nome_mae']].to_dict(orient='records')

    elif delegacia == '16a DP':
        conteudo['p16'] = conteudo['p16'] + df_final.query('delegacia == "16a DP"')[['nome_preso', 'nome_mae']].to_dict(orient='records')

    elif delegacia == '17a DP':
        conteudo['p12'] = conteudo['p12'] + df_final.query('delegacia == "17a DP"')[['nome_preso', 'nome_mae']].to_dict(orient='records')

    elif delegacia == '18a DP':
        conteudo['p15'] = conteudo['p15'] + df_final.query('delegacia == "18a DP"')[['nome_preso', 'nome_mae']].to_dict(orient='records')

    elif delegacia == '19a DP':
        conteudo['p15'] = conteudo['p15'] + df_final.query('delegacia == "19a DP"')[['nome_preso', 'nome_mae']].to_dict(orient='records')

    elif delegacia == '20a DP':
        conteudo['p20'] = conteudo['p20'] + df_final.query('delegacia == "20a DP"')[['nome_preso', 'nome_mae']].to_dict(orient='records')

    elif delegacia == '21a DP':
        conteudo['p21'] = conteudo['p21'] + df_final.query('delegacia == "21a DP"')[['nome_preso', 'nome_mae']].to_dict(orient='records')

    elif delegacia == '23a DP':
        conteudo['p15'] = conteudo['p15'] + df_final.query('delegacia == "23a DP"')[['nome_preso', 'nome_mae']].to_dict(orient='records')

    elif delegacia == '26a DP':
        conteudo['p26'] = conteudo['p26'] + df_final.query('delegacia == "26a DP"')[['nome_preso', 'nome_mae']].to_dict(orient='records')

    elif delegacia == '27a DP':
        conteudo['p27'] = conteudo['p27'] + df_final.query('delegacia == "27a DP"')[['nome_preso', 'nome_mae']].to_dict(orient='records')

    elif delegacia == '29a DP':
        conteudo['p27'] = conteudo['p27'] + df_final.query('delegacia == "29a DP"')[['nome_preso', 'nome_mae']].to_dict(orient='records')

    elif delegacia == '30a DP':
        conteudo['p30'] = conteudo['p30'] + df_final.query('delegacia == "30a DP"')[['nome_preso', 'nome_mae']].to_dict(orient='records')

    elif delegacia == '31a DP':
        conteudo['p16'] = conteudo['p16'] + df_final.query('delegacia == "31a DP"')[['nome_preso', 'nome_mae']].to_dict(orient='records')

    elif delegacia == '32a DP':
        conteudo['p26'] = conteudo['p26'] + df_final.query('delegacia == "32a DP"')[['nome_preso', 'nome_mae']].to_dict(orient='records')

    elif delegacia == '33a DP':
        conteudo['p20'] = conteudo['p20'] + df_final.query('delegacia == "33a DP"')[['nome_preso', 'nome_mae']].to_dict(orient='records')

    elif delegacia == '35a DP':
        conteudo['p13'] = conteudo['p13'] + df_final.query('delegacia == "35a DP"')[['nome_preso', 'nome_mae']].to_dict(orient='records')

    elif delegacia == 'DEAM II':
        conteudo['p15'] = conteudo['p15'] + df_final.query('delegacia == "DEAM II"')[['nome_preso', 'nome_mae']].to_dict(orient='records')
        
    
# Excluindo as chaves que ficaram vazias
delete = [key for key in conteudo if len(conteudo[key]) == 0]
for key in delete: del conteudo[key]

end_for = perf_counter()
print('laço For Time: {:.5f}'.format(end_for - start_for))
# Out:
# laço For Time: 0.02293

# %%
df_np = df_final.copy()
start_np = perf_counter()
# lst_campos = ['nome_preso', 'nome_mae']
dp_patherns = [
    (df_np['delegacia'].isin(["1a DP", "4a DP", "8a DP", "10a DP"]), 'p01'),
    (df_np['delegacia'] == '5a DP', 'p05'),
    (df_np['delegacia'] == '6a DP', 'p06'),
    (df_np['delegacia'].isin(["12a DP", "17a DP"]), 'p12'),
    (df_np['delegacia'].isin(["13a DP", "35a DP"]), 'p13'),
    (df_np['delegacia'].isin(["15a DP", "18a DP", "19a DP", "23a DP", "DEAM II"]), 'p15'),
    (df_np['delegacia'].isin(["16a DP", "31a DP"]), 'p16'),
    (df_np['delegacia'].isin(["14a DP", "20a DP", "33a DP"]), 'p20'),
    (df_np['delegacia'].isin(["11a DP", "21a DP"]), 'p21'),
    (df_np['delegacia'].isin(["26a DP", "32a DP"]), 'p26'),
    (df_np['delegacia'].isin(["27a DP", "29a DP"]), 'p27'),
    (df_np['delegacia'] == '30a DP', 'p30') 
]

dp_criteria, dp_values = zip(*dp_patherns)
df_np['dp'] = np.select(dp_criteria, dp_values, None)
# df_np['dp'] = df_np['dp'].combine_first(np.array(df_np['delegacia'].str.split('a')[0]))

end_np = perf_counter()
print('Numpy Time: {:.5f}'.format(end_np - start_np))
# Out:
# Numpy Time: 0.00300

# %%
rotas_patherns = [
    (df_np['dp'].isin(['p05', 'p06', 'p13', 'p16', 'p30']), 'leste'),
    (df_np['dp'].isin(['p12', 'p15', 'p21', 'p26']), 'oeste'),
    (df_np['dp'].isin(['p01', 'p20', 'p27']), 'sul')
]

rotas_criteria, rotas_values = zip(*rotas_patherns)
df_np['rota'] = np.select(rotas_criteria, rotas_values, None)

# %%
df_np
# Out:
#                                            nome_preso  \
# 0               CICERO NOGUEIRA FEITOSA (Prt.: 75150)
# 1       JOÃO PAULO MESQUITA DE OLIVEIRA (Prt.: 70795)
# 2                                      MATEUS MARQUES
# 3                              MARCOS MENDES DA SILVA
# 4    ALYSSON GUILHERME ALVES DOS SANTOS (Prt.: 116734
# 5                                BRUNO CRUZ DE ARAUJO
# 6                          CARLOS DANIEL SOUSA SANTOS
# 7                           WILLIAN NERES DE OLIVEIRA
# 8           CLEITON SANTIAGO DOS SANTOS (Prt.: 94284)
# 9          TARCÍSIO DE OLIVEIRA SANTOS (Prt.: 115544)
# 10        BRENO RICARDO FERREIRA CUTRIM (Prt.: 89451)
# 11                             BRUNO DOS SANTOS PINTO
# 12                WESLEY MOREIRA COSTA (Prt.: 110900)
# 13              RENATO ARAUJO DE MATOS (Prt.: 153852)
# 14                               ADÃO PEREIRA DA MOTA
# 15                   CLÊMILSON SANTANA (Prt.: 123005)
# 16  EDVAN PEREIRA DE FREITAS NASCIMENTO (Prt.: 78703)
# 17            MICHEL MAX SOUSA DA SILVA (Prt.: 62702)
# 18                             PAULO ALVES PIRES NETO
# 19                             EDSON JUNIO BUENO ROSA
# 20                             MAURO DOURADO OLIVEIRA
#
#                                   nome_mae dt_nascimento  \
# 0                   MARIA NOGUEIRA FEITOSA    01/11/1985
# 1           JOSENEIDE MESQUITA DE OLIVEIRA    30/04/1989
# 2                   MARIA ALMEIDA DA SILVA    23/12/1991
# 3                    DEYSE MENDES DE JESUS    02/01/1998
# 4             ) CLAUDINELIA ALVES DA COSTA    23/10/1996
# 5                ANA CÉLIA CRUZ DOS SANTOS    25/11/1999
# 6   MARIA DA CONCEIÇÃO SILVESTRE DOS SANTO  S 27/02/1999
# 7         JOSÉ FRANCISCO DE OLIVEIRA SOUSA    18/10/1993
# 8     TENISIA CARVALHO SANTIAGO DOS SANTOS    29/03/1994
# 9          MARIA DE FÁTIMA OLIVEIRA SANTOS    23/03/1997
# 10                   TATIANA MENDES CUTRIM    19/10/1994
# 11             MARIA DAS GRAÇAS DOS SANTOS    31/10/1991
# 12                  IVANILZA ALVES MOREIRA    01/05/1997
# 13                NOAIDE ARAUJO DOS SANTOS    08/05/1974
# 14               LIBERTINA CARDOSO DE MELO    15/04/1979
# 15                 MARIA APARECIDA SANTANA    28/10/1981
# 16     MARIA PEREIRA DE FREITAS NASCIMENTO    20/06/1984
# 17                   JANETE SOUSA DA SILVA    21/08/1982
# 18                   MARIA DE FATIMA PIRES    01/04/1973
# 19       MARIA FRANCISCA BUENO DE MESQUITA    21/12/2002
# 20                ANTONIA DOURADO OLIVEIRA    20/12/1988
#
#                      ocorrencia       dt_cadastro delegacia   dp   rota
# 0      IP No 109 / 2021 - 5a DP  01/03/2021 00:00     5a DP  p05  leste
# 1       IP No 93 / 2021 - 2a DP  01/03/2021 01:28     5a DP  p05  leste
# 2   MP No 3614316 / 2020 - DCPI  28/02/2021 23:35     5a DP  p05  leste
# 3      MP No 7316 / 2021 - DCPI  28/02/2021 16:09     6a DP  p06  leste
# 4     IP No 192 / 2021 - 13a DP  28/02/2021 19:51    13a DP  p13  leste
# 5     IP No 142 / 2021 - 35a DP  28/02/2021 19:29    13a DP  p13  leste
# 6     IP No 143 / 2021 - 35a DP  28/02/2021 19:34    13a DP  p13  leste
# 7     IP No 191 / 2021 - 13a DP  28/02/2021 19:24    13a DP  p13  leste
# 8     IP No 249 / 2021 - 17a DP  28/02/2021 19:27    12a DP  p12  oeste
# 9    MP No 510316 / 2021 - DCPI  28/02/2021 19:21    12a DP  p12  oeste
# 10    IP No 166 / 2021 - 15a DP  28/02/2021 19:00    15a DP  p15  oeste
# 11    IP No 125 / 2021 - 19a DP  28/02/2021 17:12    15a DP  p15  oeste
# 12    IP No 166 / 2021 - 15a DP  28/02/2021 18:57    15a DP  p15  oeste
# 13    IP No 156 / 2021 - 18a DP  28/02/2021 17:50    18a DP  p15  oeste
# 14   MP No 4426 / 2021 - 26a DP  28/02/2021 23:36    26a DP  p26  oeste
# 15    IP No 208 / 2021 - 26a DP  28/02/2021 19:15    26a DP  p26  oeste
# 16     IP No 126 / 2021 - 8a DP  28/02/2021 17:22     1a DP  p01    sul
# 17   MP No 290316 / 2021 - DCPI  28/02/2021 23:58    20a DP  p20    sul
# 18    IP No 148 / 2021 - 20a DP  28/02/2021 18:14    20a DP  p20    sul
# 19    IP No 277 / 2021 - 27a DP  28/02/2021 19:41    27a DP  p27    sul
# 20    IP No 278 / 2021 - 27a DP  28/02/2021 19:55    27a DP  p27    sul

# %%
route_name = ['oeste']
df_filtrado = df_np[df_np['rota'].isin(route_name)]
np.unique(df_filtrado['dp'].values)

df_np[df_np['rota'].isin(route_name)].loc[df_np['dp'] == 'p12'].reset_index()
# Out:
#    index                                  nome_preso  \
# 0      8   CLEITON SANTIAGO DOS SANTOS (Prt.: 94284)
# 1      9  TARCÍSIO DE OLIVEIRA SANTOS (Prt.: 115544)
#
#                                nome_mae dt_nascimento  \
# 0  TENISIA CARVALHO SANTIAGO DOS SANTOS    29/03/1994
# 1       MARIA DE FÁTIMA OLIVEIRA SANTOS    23/03/1997
#
#                    ocorrencia       dt_cadastro delegacia   dp   rota
# 0   IP No 249 / 2021 - 17a DP  28/02/2021 19:27    12a DP  p12  oeste
# 1  MP No 510316 / 2021 - DCPI  28/02/2021 19:21    12a DP  p12  oeste

# %%
def preenche_docx(rotas, dp):
    
    df = df_np[df_np['rota'].isin(rotas)].loc[df_np['dp'] == dp].reset_index()
    merge_content = []
    for i, row in df.iterrows():
        dict_content = {
            str(row['dp']) + '_idx': '0' + str(i + 1) if (i + 1) < 10 else str(i + 1),
            str(row['dp']) + '_nome': row['nome_preso'],
            str(row['dp']) + '_ip': '',
            str(row['dp']) + '_mp': 'NÃO',
            str(row['dp']) + '_mlj': 'NÃO',
            str(row['dp']) + '_cs': 'NÃO',
            str(row['dp']) + '_bnmp': row['nome_preso'] + ', ' + row['nome_mae']
        }
        merge_content.append(dict_content)
        
    return merge_content

# %%
preenche_docx(route_name, 'p12')
# Out:
# [{'p12_idx': '01',
#   'p12_nome': 'CLEITON SANTIAGO DOS SANTOS (Prt.: 94284)',
#   'p12_ip': '',
#   'p12_mp': 'NÃO',
#   'p12_mlj': 'NÃO',
#   'p12_cs': 'NÃO',
#   'p12_bnmp': 'CLEITON SANTIAGO DOS SANTOS (Prt.: 94284), TENISIA CARVALHO SANTIAGO DOS SANTOS'},
#  {'p12_idx': '02',
#   'p12_nome': 'TARCÍSIO DE OLIVEIRA SANTOS (Prt.: 115544)',
#   'p12_ip': '',
#   'p12_mp': 'NÃO',
#   'p12_mlj': 'NÃO',
#   'p12_cs': 'NÃO',
#   'p12_bnmp': 'TARCÍSIO DE OLIVEIRA SANTOS (Prt.: 115544), MARIA DE FÁTIMA OLIVEIRA SANTOS'}]

# %%
delete = [key for key in conteudo if len(conteudo[key]) == 0]
for key in delete: del conteudo[key]

# %%
conteudo

# %%
conteudo['p05'] = conteudo['p05'] = df_final.query('delegacia == "5a DP"')['nome_preso'].tolist()
# df_final.query('delegacia == "5a DP"')['nome_preso'].tolist()

# %%
conteudo['p05']
