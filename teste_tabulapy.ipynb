# %% [markdown]
# #  Teste da biblioteca tabula_py
#
# link de ref: https://github.com/chezou/tabula-py

# %%
# !java -version

# %%
import tabula

tabula.environment_info()
# Out:
# Python version:
#     3.8.5 (default, Sep  3 2020, 21:29:08) [MSC v.1916 64 bit (AMD64)]
# Java version:
#     java version "1.8.0_261"
# Java(TM) SE Runtime Environment (build 1.8.0_261-b12)
# Java HotSpot(TM) Client VM (build 25.261-b12, mixed mode)
# tabula-py version: 2.2.0
# platform: Windows-10-10.0.18362-SP0
# uname:
#     uname_result(system='Windows', node='DESKTOP-IU5EHTA', release='10', version='10.0.18362', machine='AMD64', processor='Intel64 Family 6 Model 69 Stepping 1, GenuineIntel')
# linux_distribution: ('', '', '')
# mac_ver: ('', ('', '', ''), '')

# %%
pdf_path = "dados/originais/solicitacao_escolta_solicitacoes_dia15.pdf"

# dfs = tabula.read_pdf(pdf_path, columns=[47, 147, 256, 310, 375, 431, 504], guess=False, pages=1)
dfs = tabula.read_pdf(pdf_path, columns=[300, 500, 600, 700, 800, 900], guess=False, pages='all')

# %%
dfs[1]
# Out:
#                                        nome_preso  \
# 0                                             NaN
# 1                                               D
# 2                                          DCCP -
# 3                                             NaN
# 4                                      AISP OESTE
# 5                              Delegacia : DCA II
# 6                                   Nome do Preso
# 7                             MENOR INFRATOR 3030
# 8   Total de presos para escolta na Delegacia : 1
# 9                              Delegacia : 12a DP
# 10                                  Nome do Preso
# 11        ANA ROBERTA SANTOS BASTOS (Prt.: 49612)
# 12          EDMILSON PEREIRA GEDIS (Prt.: 109940)
# 13       NEUSA FERREIRA DOS SANTOS (Prt.: 147436)
# 14  Total de presos para escolta na Delegacia : 3
# 15                             Delegacia : 15a DP
# 16                                  Nome do Preso
# 17  ALEXSANDRO DO NASCIMENTO COSTA (Prt.: 115000)
# 18                    FRANCISCO JONAS SILVA SOUSA
# 19       JEVERSON PEREIRA LIBERATO (Prt.: 155606)
# 20       JONADABE RIBEIRO DA SILVA (Prt.: 131649)
# 21                JONATHAN LUCAS DA SILVA FREITAS
# 22            MARCOS PAULO DE JESUS (Prt.: 31904)
# 23          RAFAEL SOUSA DE ARAUJO (Prt.: 105323)
# 24  Total de presos para escolta na Delegacia : 7
# 25                             Delegacia : 21a DP
# 26                                  Nome do Preso
# 27          ALDEMIR MOREIRA DA CRUZ (Prt.: 72578)
# 28                                            NaN
# 29                                            NaN
# 30                                            NaN
#
#                                       nome_mae  dt_nascimento  \
# 0                POLÍCIA CIVIL DO DISTRITO FED           ERAL
# 1                  EPARTAMENTO DE ATIVIDADES E       SPECIAIS
# 2                  DIVISÃO DE CONTROLE E CUSTÓ  DIA DE PRESOS
# 3                   Relação de presos para esc           olta
# 4                                          NaN            NaN
# 5                                          NaN            NaN
# 6                                  Nome da Mãe      Dt. Nasc.
# 7                                          NaN            NaN
# 8                                          NaN            NaN
# 9                                          NaN            NaN
# 10                                 Nome da Mãe      Dt. Nasc.
# 11                          IDALINA DOS SANTOS     08/09/1977
# 12                         ANICETA MARIA GEDIS     14/02/1980
# 13                  TEREZA FERREIRA DOS SANTOS     15/12/1966
# 14                                         NaN            NaN
# 15                                         NaN            NaN
# 16                                 Nome da Mãe      Dt. Nasc.
# 17            REGINA CELIA DO NASCIMENTO COSTA     27/07/1994
# 18               JOANA DARC VERÍSSIMO DA SILVA     25/05/1997
# 19                    VANESSA PEREIRA DA SILVA     22/12/1993
# 20             MARIA DE LOURDES VIDAL DA SILVA     20/04/1989
# 21                ILDA FELIX DA SILVA SOBRINHO     28/06/1999
# 22                       MARIA HELENA DE JESUS     07/04/1979
# 23                      SIMONE DE SOUSA ARAUJO     26/07/1988
# 24                                         NaN            NaN
# 25                                         NaN            NaN
# 26                                 Nome da Mãe      Dt. Nasc.
# 27                  MARIA NEUZA DA CRUZ SANTOS     24/09/1992
# 28                                Pagina 2 / 5            NaN
# 29  "Brasília - Patrimônio Cultural da Humanid           ade"
# 30                         15/02/2021 05:32:32            NaN
#
#                    ocorrencia       dt_cadastro delegacia
# 0                         NaN               NaN       NaN
# 1                         NaN               NaN       NaN
# 2                         NaN               NaN       NaN
# 3                         NaN               NaN       NaN
# 4              Data da Escolt    a : 15/02/2021       NaN
# 5                         NaN               NaN       NaN
# 6                  Ocorrência  Dt/Hora Cadastro       NaN
# 7                         NaN  15/02/2021 00:52    26a DP
# 8                         NaN               NaN    26a DP
# 9                         NaN               NaN    26a DP
# 10                 Ocorrência  Dt/Hora Cadastro    26a DP
# 11   IP No 96 / 2021 - 12a DP  15/02/2021 00:18    26a DP
# 12   IP No 97 / 2021 - 12a DP  15/02/2021 03:48    26a DP
# 13   IP No 96 / 2021 - 12a DP  15/02/2021 00:18    26a DP
# 14                        NaN               NaN    26a DP
# 15                        NaN               NaN    26a DP
# 16                 Ocorrência  Dt/Hora Cadastro    26a DP
# 17  IP No 101 / 2021 - 19a DP  14/02/2021 20:03    26a DP
# 18  IP No 130 / 2021 - 15a DP  14/02/2021 19:58    26a DP
# 19  IP No 130 / 2021 - 15a DP  14/02/2021 20:02    26a DP
# 20  IP No 130 / 2021 - 15a DP  14/02/2021 19:59    26a DP
# 21  IP No 129 / 2021 - 15a DP  14/02/2021 17:10    26a DP
# 22  IP No 130 / 2021 - 15a DP  14/02/2021 19:57    26a DP
# 23  IP No 130 / 2021 - 15a DP  14/02/2021 20:01    26a DP
# 24                        NaN               NaN    26a DP
# 25                        NaN               NaN    26a DP
# 26                 Ocorrência  Dt/Hora Cadastro    26a DP
# 27  IP No 223 / 2021 - 21a DP  14/02/2021 19:01    26a DP
# 28                        NaN               NaN    26a DP
# 29                        NaN               NaN    26a DP
# 30                        NaN               NaN    26a DP

# %%
from numpy import nan

# %%
dfs[1].columns = ['nome_preso', 'nome_mae', 'dt_nascimento', 'ocorrencia', 'dt_cadastro']

# %%
dfs[1]['delegacia'] = nan

# %%
dfs[2]
# Out:
#                                        nome_preso  \
# 0                                             NaN
# 1                                               D
# 2                                          DCCP -
# 3                                             NaN
# 4                                      AISP OESTE
# 5                                      JOÃO SOUZA
# 6   Total de presos para escolta na Delegacia : 2
# 7                              Delegacia : 26a DP
# 8                                   Nome do Preso
# 9                       MARCELO MAGALHAES BARROSO
# 10  Total de presos para escolta na Delegacia : 1
# 11                                            NaN
# 12                                            NaN
# 13                                            NaN
#
#                                       nome_mae  dt_nascimento  \
# 0                POLÍCIA CIVIL DO DISTRITO FED           ERAL
# 1                  EPARTAMENTO DE ATIVIDADES E       SPECIAIS
# 2                  DIVISÃO DE CONTROLE E CUSTÓ  DIA DE PRESOS
# 3                   Relação de presos para esc           olta
# 4                                          NaN            NaN
# 5                         MARIA AUGUSTA FARIAS     08/02/1958
# 6                                          NaN            NaN
# 7                                          NaN            NaN
# 8                                  Nome da Mãe      Dt. Nasc.
# 9           MARIA DE LOURDES MAGALHAES BARROSO     08/07/1978
# 10                                         NaN            NaN
# 11                                Pagina 3 / 5            NaN
# 12  "Brasília - Patrimônio Cultural da Humanid           ade"
# 13                         15/02/2021 05:32:32            NaN
#
#                      ocorrencia       dt_cadastro  delegacia
# 0                           NaN               NaN        NaN
# 1                           NaN               NaN        NaN
# 2                           NaN               NaN        NaN
# 3                           NaN               NaN        NaN
# 4                Data da Escolt    a : 15/02/2021        NaN
# 5   MP No 11421 / 2021 - 21a DP  14/02/2021 19:52        NaN
# 6                           NaN               NaN        NaN
# 7                           NaN               NaN        NaN
# 8                    Ocorrência  Dt/Hora Cadastro        NaN
# 9     IP No 134 / 2021 - 32a DP  14/02/2021 09:19        NaN
# 10                          NaN               NaN        NaN
# 11                          NaN               NaN        NaN
# 12                          NaN               NaN        NaN
# 13                          NaN               NaN        NaN

# %%
df_delegacias = dfs[2].iloc[:,0].where(dfs[2].iloc[:, 0].str.contains('^Delegacia', na=False)).dropna()
idx_del = df_delegacias.index.to_list()
df_delegacias.index.max()
df_delegacias

# s_delegacia = dfs[0].iloc[:,3].where(dfs[0].iloc[:, 3].str.contains(' DP', na=False)).dropna()
# for i,v in s_delegacia.items():
#     s_delegacia[i] = v.split(' - ')[1]
    
# s_delegacia
# Out:
# 7    Delegacia : 26a DP
# Name: nome_preso, dtype: object

# %%
def verifica_presos_folha_anterior(df_folha_atual, df_delegacias):

    str_total_presos = df_folha_atual.iloc[:,0].where(df_folha_atual.iloc[:, 0].str.contains('^Total de presos para escolta na Delegacia', na=False)).dropna()

    presos_folha_anterior = -1
    for idx_total in str_total_presos.index.tolist():
        if idx_total < df_delegacias.index.min():
            presos_folha_anterior = idx_total

    return presos_folha_anterior

# %%
pfa = verifica_presos_folha_anterior(dfs[2], df_delegacias)
# pfa
dfs[2].iloc[:pfa, 5] = dfs[1].iloc[-1, 5]
dfs[2]
# Out:
#                                        nome_preso  \
# 0                                             NaN
# 1                                               D
# 2                                          DCCP -
# 3                                             NaN
# 4                                      AISP OESTE
# 5                                      JOÃO SOUZA
# 6   Total de presos para escolta na Delegacia : 2
# 7                              Delegacia : 26a DP
# 8                                   Nome do Preso
# 9                       MARCELO MAGALHAES BARROSO
# 10  Total de presos para escolta na Delegacia : 1
# 11                                            NaN
# 12                                            NaN
# 13                                            NaN
#
#                                       nome_mae  dt_nascimento  \
# 0                POLÍCIA CIVIL DO DISTRITO FED           ERAL
# 1                  EPARTAMENTO DE ATIVIDADES E       SPECIAIS
# 2                  DIVISÃO DE CONTROLE E CUSTÓ  DIA DE PRESOS
# 3                   Relação de presos para esc           olta
# 4                                          NaN            NaN
# 5                         MARIA AUGUSTA FARIAS     08/02/1958
# 6                                          NaN            NaN
# 7                                          NaN            NaN
# 8                                  Nome da Mãe      Dt. Nasc.
# 9           MARIA DE LOURDES MAGALHAES BARROSO     08/07/1978
# 10                                         NaN            NaN
# 11                                Pagina 3 / 5            NaN
# 12  "Brasília - Patrimônio Cultural da Humanid           ade"
# 13                         15/02/2021 05:32:32            NaN
#
#                      ocorrencia       dt_cadastro delegacia
# 0                           NaN               NaN    26a DP
# 1                           NaN               NaN    26a DP
# 2                           NaN               NaN    26a DP
# 3                           NaN               NaN    26a DP
# 4                Data da Escolt    a : 15/02/2021    26a DP
# 5   MP No 11421 / 2021 - 21a DP  14/02/2021 19:52    26a DP
# 6                           NaN               NaN       NaN
# 7                           NaN               NaN       NaN
# 8                    Ocorrência  Dt/Hora Cadastro       NaN
# 9     IP No 134 / 2021 - 32a DP  14/02/2021 09:19       NaN
# 10                          NaN               NaN       NaN
# 11                          NaN               NaN       NaN
# 12                          NaN               NaN       NaN
# 13                          NaN               NaN       NaN

# %%
lista = iter(idx_del)
primeiro = next(lista, 'fim')
# next_val = next(lista, 'fim')
while True:
    next_val = next(lista, 'fim')
    if next_val == 'fim':
        dfs[1].iloc[primeiro:, 5] = df_delegacias[primeiro].split(' : ')[1]
        break
    else:
        dfs[1].iloc[primeiro:next_val, 5] = df_delegacias[primeiro].split(' : ')[1]
        primeiro = next_val
#         next_val = next(lista, 'fim')

# %%
dfs[1]

# %%
def trata_df_pdf(dfs_list):
    
    dfs = dfs_list.copy()
    
    for i in range(len(dfs)):
        
        dfs[i].columns = ['nome_preso', 'nome_mae', 'dt_nascimento', 'ocorrencia', 'dt_cadastro']
        dfs[i]['delegacia'] = nan
        df_delegacias = dfs[i].iloc[:,0].where(dfs[i].iloc[:, 0].str.contains('^Delegacia', na=False)).dropna()
        
        if len(df_delegacias) > 0:
            
            pfa = verifica_presos_folha_anterior(dfs[i], df_delegacias) # presos da folha anterior
            if pfa > -1 :
                dfs[i].iloc[pfa-1, 5] = dfs[i-1].iloc[-1, 5]
                
            idx_del = df_delegacias.index.to_list()
            lista = iter(idx_del)
            primeiro = next(lista, 'fim')
            
            while True:
                next_val = next(lista, 'fim')
                if next_val == 'fim':
                    dfs[i].iloc[primeiro:, 5] = df_delegacias[primeiro].split(' : ')[1]
                    break
                else:
                    dfs[i].iloc[primeiro:next_val, 5] = df_delegacias[primeiro].split(' : ')[1]
                    primeiro = next_val
        else:
            dfs[i].iloc[:, 5] = dfs[i-1].iloc[-1, 5]

        dfs[i] = dfs[i].loc[dfs[i]['nome_preso'] != 'Nome do Preso']
        dfs[i].dropna(inplace=True)

        # trantando as colunas
        dfs[i]['nome_preso'] = dfs[i]['nome_preso'].str.strip()
    return dfs

# %%
df_tratados = trata_df_pdf(dfs)

# %%
df_tratados[2]

# %%
import pandas as pd
df_final = pd.concat(df_tratados, ignore_index=True)
# for i in range(1, len(df_tratados)):
#     df_tratados[0].concat(df_tratados[i], ignore_index=True)

# %%
df_final
# Out:
#                                           nome_preso  \
# 0                         CLAUDENIR DOS SANTOS COSTA
# 1              CLEBER FARIAS DA PAIXÃO (Prt.: 34064)
# 2              FABIO DELFINO DA SILVA (Prt.: 102279)
# 3                ANTONIO LUCIANO ALVES (Prt.: 87671)
# 4               FELIPE PEDROSO FARIAS (Prt.: 138454)
# 5   HERIKO DAS NEVES ARRUDA DOS SANTOS (Prt.: 36494)
# 6                         LUAN PEREIRA DO NASCIMENTO
# 7      RONALDO ADRIANO BONOTO MONTEIRO (Prt.: 83428)
# 8            VALDECIO BRASIL DA SILVA (Prt.: 149955)
# 9                             WESLEI DA SILVA SANTOS
# 10                     VITÓRIO JOAQUIM DE LIMA COSTA
# 11           ANA ROBERTA SANTOS BASTOS (Prt.: 49612)
# 12             EDMILSON PEREIRA GEDIS (Prt.: 109940)
# 13          NEUSA FERREIRA DOS SANTOS (Prt.: 147436)
# 14     ALEXSANDRO DO NASCIMENTO COSTA (Prt.: 115000)
# 15                       FRANCISCO JONAS SILVA SOUSA
# 16          JEVERSON PEREIRA LIBERATO (Prt.: 155606)
# 17          JONADABE RIBEIRO DA SILVA (Prt.: 131649)
# 18                   JONATHAN LUCAS DA SILVA FREITAS
# 19               MARCOS PAULO DE JESUS (Prt.: 31904)
# 20             RAFAEL SOUSA DE ARAUJO (Prt.: 105323)
# 21             ALDEMIR MOREIRA DA CRUZ (Prt.: 72578)
# 22                                        JOÃO SOUZA
# 23                         MARCELO MAGALHAES BARROSO
# 24  RAFAEL VENANCIO DE AQUINO OLIVEIRA (Prt.: 78471)
# 25               ROBSON ABÍLIO LACERDA (Prt.: 51082)
# 26                           LEONARDO LOPES FERREIRA
# 27                   MARIA DE LOURDES ALVES DE SOUSA
# 28                   PAULO ROBERTO CHAVES DE FREITAS
# 29                              BRENDOW SANTOS MOURA
# 30          LEANDRO BRANDÃO DE ANDRADE (Prt.: 32848)
# 31          LUCIANO DA SILVA RODRIGUES (Prt.: 73827)
# 32                         RAFAEL FERREIRA FERNANDES
#
#                                nome_mae dt_nascimento  \
# 0                     JOSEFA DOS SANTOS    29/04/1999
# 1               EVANDA ABADIA DE FARIAS    11/02/1980
# 2              AURORA GERONIMA DA SILVA    18/01/1974
# 3                VICENÇA PAULA DA SILVA    14/06/1980
# 4               ELISANGELA DIAS PEDROSO    20/01/1996
# 5   CENILDA DAS NEVES ARRUDA DOS SANTOS    31/10/1984
# 6         IOLANDA PEREIRA DO NASCIMENTO    16/08/1987
# 7                 IRENE BONOTO MONTEIRO    28/03/1978
# 8              ROSELI FERREIRA DA SILVA    05/08/1977
# 9                 ELIETE MARIA DA SILVA    08/04/1999
# 10       MARIA DO SOCORRO DE LIMA COSTA    10/02/1991
# 11                   IDALINA DOS SANTOS    08/09/1977
# 12                  ANICETA MARIA GEDIS    14/02/1980
# 13           TEREZA FERREIRA DOS SANTOS    15/12/1966
# 14     REGINA CELIA DO NASCIMENTO COSTA    27/07/1994
# 15        JOANA DARC VERÍSSIMO DA SILVA    25/05/1997
# 16             VANESSA PEREIRA DA SILVA    22/12/1993
# 17      MARIA DE LOURDES VIDAL DA SILVA    20/04/1989
# 18         ILDA FELIX DA SILVA SOBRINHO    28/06/1999
# 19                MARIA HELENA DE JESUS    07/04/1979
# 20               SIMONE DE SOUSA ARAUJO    26/07/1988
# 21           MARIA NEUZA DA CRUZ SANTOS    24/09/1992
# 22                 MARIA AUGUSTA FARIAS    08/02/1958
# 23   MARIA DE LOURDES MAGALHAES BARROSO    08/07/1978
# 24         ANA LUCIA DE AQUINO OLIVEIRA    16/08/1990
# 25        MARIA GORETE DE LACERDA SILVA    30/12/1987
# 26                  ADRIANA CUNHA LOPES    12/07/2002
# 27              CUSTÓDIA ALVES DE SOUSA    17/02/1977
# 28        MARIA DAYSE CHAVES DE FREITAS    10/10/1968
# 29              ELIZANGELA SANTOS ALVES    20/05/1999
# 30            CLEONICE DE SOUZA BRANDÃO    16/08/1984
# 31      MARIA DE JESUS PEREIRA DA SILVA    20/05/1992
# 32          MARLENE FERREIRA DOS SANTOS    03/12/1989
#
#                      ocorrencia       dt_cadastro delegacia
# 0      IP No 258 / 2021 - 6a DP  15/02/2021 02:10     6a DP
# 1      IP No 256 / 2021 - 6a DP  15/02/2021 01:44     6a DP
# 2      IP No 257 / 2021 - 6a DP  15/02/2021 01:32     6a DP
# 3     IP No 180 / 2021 - 16a DP  14/02/2021 18:29    16a DP
# 4     IP No 165 / 2021 - 31a DP  14/02/2021 16:19    16a DP
# 5     IP No 167 / 2021 - 31a DP  15/02/2021 02:29    16a DP
# 6     IP No 165 / 2021 - 31a DP  14/02/2021 16:20    16a DP
# 7   MP No 3625316 / 2020 - DCPI  15/02/2021 02:33    16a DP
# 8     IP No 182 / 2021 - 16a DP  15/02/2021 02:29    16a DP
# 9     IP No 181 / 2021 - 16a DP  14/02/2021 21:02    16a DP
# 10   MP No 5431 / 2021 - 31a DP  14/02/2021 19:21    31a DP
# 11     IP No 96 / 2021 - 12a DP  15/02/2021 00:18    12a DP
# 12     IP No 97 / 2021 - 12a DP  15/02/2021 03:48    12a DP
# 13     IP No 96 / 2021 - 12a DP  15/02/2021 00:18    12a DP
# 14    IP No 101 / 2021 - 19a DP  14/02/2021 20:03    15a DP
# 15    IP No 130 / 2021 - 15a DP  14/02/2021 19:58    15a DP
# 16    IP No 130 / 2021 - 15a DP  14/02/2021 20:02    15a DP
# 17    IP No 130 / 2021 - 15a DP  14/02/2021 19:59    15a DP
# 18    IP No 129 / 2021 - 15a DP  14/02/2021 17:10    15a DP
# 19    IP No 130 / 2021 - 15a DP  14/02/2021 19:57    15a DP
# 20    IP No 130 / 2021 - 15a DP  14/02/2021 20:01    15a DP
# 21    IP No 223 / 2021 - 21a DP  14/02/2021 19:01    21a DP
# 22  MP No 11421 / 2021 - 21a DP  14/02/2021 19:52    21a DP
# 23    IP No 134 / 2021 - 32a DP  14/02/2021 09:19    26a DP
# 24      IP No 96 / 2021 - 8a DP  14/02/2021 19:15     1a DP
# 25      IP No 68 / 2021 - 4a DP  14/02/2021 20:21     1a DP
# 26    IP No 112 / 2021 - 20a DP  14/02/2021 21:51    20a DP
# 27    IP No 186 / 2021 - 29a DP  15/02/2021 03:33    27a DP
# 28    IP No 187 / 2021 - 29a DP  15/02/2021 05:09    27a DP
# 29   IP No 835 / 2021 - DEAM II  15/02/2021 03:42   DEAM II
# 30   IP No 832 / 2021 - DEAM II  14/02/2021 20:17   DEAM II
# 31   IP No 830 / 2021 - DEAM II  14/02/2021 17:26   DEAM II
# 32   IP No 836 / 2021 - DEAM II  15/02/2021 04:29   DEAM II

# %%
df_final.query('delegacia == "5a DP"')['nome_preso'].tolist()

# %%
df_final['delegacia'].unique().tolist()

# %%
conteudo = {}
for p in range(1,40):
    chave = 'p0'+str(p) if p < 10 else 'p'+str(p)
    conteudo[chave] = []

    
lst_delegacias = df_final['delegacia'].unique().tolist()
for delegacia in lst_delegacias:
    
    if delegacia == '1a DP':
        conteudo['p01'] = conteudo['p01'] + df_final.query('delegacia == "1a DP"')['nome_preso'].tolist()
        
    if delegacia == '5a DP':
        conteudo['p05'] = conteudo['p05'] + df_final.query('delegacia == "5a DP"')['nome_preso'].tolist()
        
    elif delegacia == '6a DP':
        conteudo['p06'] = conteudo['p06'] + df_final.query('delegacia == "6a DP"')['nome_preso'].tolist()
    
    elif delegacia == '11a DP':
        conteudo['p21'] = conteudo['p21'] + df_final.query('delegacia == "11a DP"')['nome_preso'].tolist()
    
    elif delegacia == '12a DP':
        conteudo['p12'] = conteudo['p12'] + df_final.query('delegacia == "12a DP"')['nome_preso'].tolist()
        
    elif delegacia == '13a DP':
        conteudo['p13'] = conteudo['p13'] + df_final.query('delegacia == "13a DP"')['nome_preso'].tolist()
        
    elif delegacia == '14a DP':
        conteudo['p20'] = conteudo['p20'] + df_final.query('delegacia == "14a DP"')['nome_preso'].tolist()
        
    elif delegacia == '15a DP':
        conteudo['p15'] = conteudo['p15'] + df_final.query('delegacia == "15a DP"')['nome_preso'].tolist()
        
    elif delegacia == '16a DP':
        conteudo['p16'] = conteudo['p16'] + df_final.query('delegacia == "16a DP"')['nome_preso'].tolist()
        
    elif delegacia == '17a DP':
        conteudo['p12'] = conteudo['p12'] + df_final.query('delegacia == "17a DP"')['nome_preso'].tolist()
        
    elif delegacia == '18a DP':
        conteudo['p18'] = conteudo['p18'] + df_final.query('delegacia == "18a DP"')['nome_preso'].tolist()
        
    elif delegacia == '19a DP':
        conteudo['p15'] = conteudo['p15'] + df_final.query('delegacia == "19a DP"')['nome_preso'].tolist()
        
    elif delegacia == '20a DP':
        conteudo['p20'] = conteudo['p20'] + df_final.query('delegacia == "20a DP"')['nome_preso'].tolist()
        
    elif delegacia == '21a DP':
        conteudo['p21'] = conteudo['p21'] + df_final.query('delegacia == "21a DP"')['nome_preso'].tolist()
        
    elif delegacia == '26a DP':
        conteudo['p26'] = conteudo['p26'] + df_final.query('delegacia == "26a DP"')['nome_preso'].tolist()
        
    elif delegacia == '27a DP':
        conteudo['p27'] = conteudo['p27'] + df_final.query('delegacia == "27a DP"')['nome_preso'].tolist()
        
    elif delegacia == '29a DP':
        conteudo['p27'] = conteudo['p27'] + df_final.query('delegacia == "29a DP"')['nome_preso'].tolist()
        
    elif delegacia == '30a DP':
        conteudo['p30'] = conteudo['p30'] + df_final.query('delegacia == "30a DP"')['nome_preso'].tolist()
        
    elif delegacia == '31a DP':
        conteudo['p16'] = conteudo['p16'] + df_final.query('delegacia == "31a DP"')['nome_preso'].tolist()
        
    elif delegacia == '32a DP':
        conteudo['p26'] = conteudo['p26'] + df_final.query('delegacia == "32a DP"')['nome_preso'].tolist()
        
    elif delegacia == '33a DP':
        conteudo['p20'] = conteudo['p20'] + df_final.query('delegacia == "33a DP"')['nome_preso'].tolist()
        
    elif delegacia == '35a DP':
        conteudo['p13'] = conteudo['p13'] + df_final.query('delegacia == "35a DP"')['nome_preso'].tolist()
        
    elif delegacia == 'DEAM II':
        conteudo['p15'] = conteudo['p15'] + df_final.query('delegacia == "DEAM II"')['nome_preso'].tolist()

# %%
conteudo

# %%
delete = [key for key in conteudo if len(conteudo[key]) == 0]
for key in delete: del conteudo[key]

# %%
conteudo

# %%
conteudo['p05'] = conteudo['p05'] = df_final.query('delegacia == "5a DP"')['nome_preso'].tolist()
# df_final.query('delegacia == "5a DP"')['nome_preso'].tolist()

# %%
conteudo['p05']
